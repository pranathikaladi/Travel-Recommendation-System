# %%
import os
import numpy as np
import pandas as pd
import scipy.sparse
from scipy.spatial.distance import correlation

# %%
data=pd.read_csv('clean_travel_data.csv')
data.head()
# Out:
#                location                          place          state  \
# 0      Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
# 1           maitri bagh         Near to Maroda, Bhilai   chhattisgarh
# 2      Tirathgarh Falls                Bastar district   chhattisgarh
# 3  Sirpur Heritage Site    bank of holy Mahanadi river   chhattisgarh
# 4     Rajeev Smriti Van                         Raipur   chhattisgarh
#
#    location_rating  age                             season affordable  \
# 0              4.0    0                             winter        Yes
# 1              4.0   20  summer,spring,winter,rainy,autumn        Yes
# 2              4.6   25                            monsoon        Yes
# 3              5.0    0                             winter        Yes
# 4              3.9    0  summer,spring,winter,rainy,autumn        Yes
#
#   types_of_travel religion  itemId
# 0          family    hindu       1
# 1         friends      any       2
# 2         friends      any       3
# 3          family    hindu       4
# 4            solo      any       5

# %%
data1=pd.read_csv('collaborative.csv')
data1.head()
# Out:
#    userId  itemId  rating  timestamp
# 0       1       1     NaN  881250949
# 1       1       2     3.0  891717742
# 2       1       3     1.0  878887116
# 3       1       4     NaN  880606923
# 4       1       5     1.0  886397596

# %%
data=pd.merge(data,data1,left_on='itemId',right_on="itemId")
data.head()
# Out:
#            location                          place          state  \
# 0  Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
# 1  Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
# 2  Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
# 3  Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
# 4  Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
#
#    location_rating  age  season affordable types_of_travel religion  itemId  \
# 0              4.0    0  winter        Yes          family    hindu       1
# 1              4.0    0  winter        Yes          family    hindu       1
# 2              4.0    0  winter        Yes          family    hindu       1
# 3              4.0    0  winter        Yes          family    hindu       1
# 4              4.0    0  winter        Yes          family    hindu       1
#
#    userId  rating  timestamp
# 0       1     NaN  881250949
# 1       2     3.0  891717742
# 2       3     1.0  878887116
# 3       4     NaN  880606923
# 4       5     1.0  886397596

# %%
data=pd.DataFrame.sort_values(data,['userId','itemId'])
data
# Out:
#                   location                          place          state  \
# 0         Bhoramdeo Temple  Chaura village, Kawardha town   chhattisgarh
# 10             maitri bagh         Near to Maroda, Bhilai   chhattisgarh
# 20        Tirathgarh Falls                Bastar district   chhattisgarh
# 30    Sirpur Heritage Site    bank of holy Mahanadi river   chhattisgarh
# 40       Rajeev Smriti Van                         Raipur   chhattisgarh
# ...                    ...                            ...            ...
# 2819            Jal Mandir                       Pawapuri          Bihar
# 2829               Hajipur                        Hajipur          Bihar
# 2839      Karkat Waterfall                    Karkathgarh          Bihar
# 2849     Dhungeswari hills                         Larpur          Bihar
# 2859          Patna Musuem                          Patna          Bihar
#
#       location_rating  age                             season affordable  \
# 0                 4.0    0                             winter        Yes
# 10                4.0   20  summer,spring,winter,rainy,autumn        Yes
# 20                4.6   25                            monsoon        Yes
# 30                5.0    0                             winter        Yes
# 40                3.9    0  summer,spring,winter,rainy,autumn        Yes
# ...               ...  ...                                ...        ...
# 2819              4.1   30                            monsoon        Yes
# 2829              3.9   25  summer,spring,winter,rainy,autumn        Yes
# 2839              4.5   20                            monsoon        Yes
# 2849              4.0   20  summer,spring,winter,rainy,autumn        Yes
# 2859              4.3    0  summer,spring,winter,rainy,autumn        Yes
#
#           types_of_travel                        religion  itemId  userId  \
# 0                  family                           hindu       1       1
# 10                friends                             any       2       1
# 20                friends                             any       3       1
# 30                 family                           hindu       4       1
# 40                   solo                             any       5       1
# ...                   ...                             ...     ...     ...
# 2819  solo,family,friends                           jains     284      10
# 2829  friends,family,solo  hindus,muslims,buddhists,jains     285      10
# 2839              friends                             any     286      10
# 2849       friends,family                       buddhists     287      10
# 2859  friends,family,solo                             any     288      10
#
#       rating  timestamp
# 0        NaN  881250949
# 10       3.0  891717742
# 20       1.0  878887116
# 30       NaN  880606923
# 40       1.0  886397596
# ...      ...        ...
# 2819     NaN  891352093
# 2829     4.0  886122952
# 2839     1.0  878961814
# 2849     1.0  884140579
# 2859     NaN  879456199
#
# [2860 rows x 13 columns]

# %%
userItemRatingMatrix=pd.pivot_table(data, values='rating',index=['userId'], columns=['itemId'])

# %%
def similarity(user1,user2):
    try:
        user1=np.array(user1)-np.nanmean(user1)
        user2=np.array(user2)-np.nanmean(user2)
        commonItemIds=[i for i in range(len(user1)) if user1[i]>0 and user2[i]>0]
        if len(commonItemIds)==0:
           return 0
        else:
           user1=np.array([user1[i] for i in commonItemIds])
           user2=np.array([user2[i] for i in commonItemIds])
           return correlation(user1,user2)
    except ZeroDivisionError:
        print("You can't divide by zero!")

# %%
def nearestNeighbourRatings(activeUser,K):
    try:
        similarityMatrix=pd.DataFrame(index=userItemRatingMatrix.index,columns=['Similarity'])
        for i in userItemRatingMatrix.index:
            similarityMatrix.loc[i]=similarity(userItemRatingMatrix.loc[activeUser],userItemRatingMatrix.loc[i])
        similarityMatrix=pd.DataFrame.sort_values(similarityMatrix,['Similarity'],ascending=[0])
        nearestNeighbours=similarityMatrix[:K]
        neighbourItemRatings=userItemRatingMatrix.loc[nearestNeighbours.index]
        predictItemRating=pd.DataFrame(index=userItemRatingMatrix.columns, columns=['Rating'])
        for i in userItemRatingMatrix.columns:
            predictedRating=np.nanmean(userItemRatingMatrix.loc[activeUser])
            for j in neighbourItemRatings.index:
                if userItemRatingMatrix.loc[j,i]>0:
                   predictedRating += (userItemRatingMatrix.loc[j,i]-np.nanmean(userItemRatingMatrix.loc[j]))*nearestNeighbours.loc[j,'Similarity']
                predictItemRating.loc[i,'Rating']=predictedRating
    except ZeroDivisionError:
        print("You can't divide by zero!")            
    return predictItemRating

# %%
def topNRecommendations(activeUser,N):
    try:
        predictItemRating=nearestNeighbourRatings(activeUser,N)
        placeAlreadyWatched=list(userItemRatingMatrix.loc[activeUser].loc[userItemRatingMatrix.loc[activeUser]>0].index)
        predictItemRating=predictItemRating.drop(placeAlreadyWatched)
        topRecommendations=pd.DataFrame.sort_values(predictItemRating,['Rating'],ascending=[0])[:N]
        topRecommendationTitles=(data.loc[data1.itemId.isin(topRecommendations.index)])
    except ZeroDivisionError:
        print("You can't divide by zero!")
    return list([topRecommendationTitles.location,topRecommendationTitles.place,topRecommendationTitles.state,topRecommendationTitles.location_rating])

# %%
activeUser=int(input("Enter userid: "))
# Out:
# Enter userid: 4

# %%
print("The recommended places for you are: ")
topN=pd.DataFrame(topNRecommendations(activeUser,4))
topN=topN.T
topN=topN.sort_values(by='location_rating', ascending=False)
topN
# Out:
# The recommended places for you are:
#                            location                 place              state  \
# 58                    Palolem Beach              Canacona                Goa
# 2081          Rajbari National Park               Belonia            Tripura
# 419                  Tirthan Valley                Kullu    Himachal pradesh
# 997             Panna National Park       Gwalior,Bhopal     Madhya Pradesh
# 2370                  Srisailam Dam             Srisailam     Andhra Pradesh
# 2391                           SHAR          Srihari Kota     Andhra Pradesh
# 2153                   mecca masjid             hyderabad          telangana
# 1286                 Shirui Kashong                Ukhrul            Manipur
# 1792             mukteswara temple            bhudaneswar             odisha
# 1780                   golden beach                  puri             odisha
# 347                    jakhu temple                shimla   Himachal pradesh
# 657                           hampi          Vijayanagara          Karnataka
# 2647    Tocklai Tea Research Centre                Jorhat              Assam
# 130           Naval Aviation Museum         Vasco da Gama                Goa
# 368             Manikaran Gurudwara                Kullu    Himachal pradesh
# 636                          mysore                mysore          Karnataka
# 2358                    Borra Caves                 Araku     Andhra Pradesh
# 2069                        Unakoti           Kailashahar            Tripura
# 708                       jog falls            Shivamogga          Karnataka
# 1813  udaygiri and khandagiri caves           bhudaneswar             odisha
# 2102                      charminar             hyderabad          telangana
# 1491                Tuirihiau falls              Serchhip            Mizoram
# 2659           Guwahati Planetarium              Guwahati              Assam
# 2731                      Bodh Gaya                  Gaya              Bihar
# 1864                   shilloi lake        lustam village           nagaland
# 1202    Keibul Lamjao National Park             Bishnupur            Manipur
# 1214                    Kangla Fort                Imphal            Manipur
# 2442         Namdapha National Park               Namdaph  Arunachal Pradesh
# 913                       Khajuraho  Chhatarpur district     Madhya Pradesh
# 2680                  Haflong Hills               Haflong              Assam
# 79                      Fort Aguada              Candolim                Goa
# 624                        Banglore              Banglore          Karnataka
# 335                   Solang Valley                Manali   Himachal pradesh
# 1503          Intanki National Park                 Peren           Nagaland
# 946                          Sanchi                Bhopal    Madhya Pradesh
# 1235           Manipur State Museum                Imphal            Manipur
# 46                Rajeev Smriti Van                Raipur       chhattisgarh
# 925                          Orchha                Jhansi    Madhya Pradesh
# 1524          Nagaland State Museum                Kohima           Nagaland
# 1575       Nagaland Zoological Park               Dimapur           Nagaland
#
#      location_rating
# 58                 5
# 2081               5
# 419                5
# 997              4.8
# 2370             4.7
# 2391             4.7
# 2153             4.7
# 1286             4.6
# 1792             4.6
# 1780             4.5
# 347              4.5
# 657              4.5
# 2647             4.5
# 130              4.5
# 368              4.5
# 636              4.5
# 2358             4.5
# 2069             4.5
# 708              4.5
# 1813             4.4
# 2102             4.4
# 1491             4.4
# 2659             4.3
# 2731             4.3
# 1864             4.3
# 1202             4.3
# 1214             4.3
# 2442             4.3
# 913              4.2
# 2680             4.2
# 79               4.2
# 624                4
# 335                4
# 1503               4
# 946                4
# 1235               4
# 46               3.9
# 925              3.9
# 1524             3.8
# 1575             3.7

# %%
def favoritePlace(activeUser,N):
    topPlace=pd.DataFrame.sort_values(data[data.userId==activeUser],['rating'],ascending=[0])[:N]
    return list([topPlace.location,topPlace.place,topPlace.state,topPlace.location_rating])

# %%
print("The recommended places for you are: ")
fav_place=pd.DataFrame(favoritePlace(activeUser,4))
fav_place=fav_place.T
fav_place=fav_place.sort_values(by='location_rating', ascending=False)
fav_place
# Out:
# The recommended places for you are:
#                 location      place            state location_rating
# 743              bijapur    bijapur        Karnataka             4.5
# 503             Pahalgam   Anantnag  Jammu & Kashmir             4.5
# 533             Sonamarg  Ganderbal  Jammu & Kashmir             4.5
# 963  Kanha National Park   jabalpur  Madhya Pradesh              4.4
